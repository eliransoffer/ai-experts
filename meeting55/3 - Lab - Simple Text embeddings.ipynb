# %% [markdown]
# # Exercise: Sentence Embedding Using GloVe and Simple Averaging
#
# **Task:**
# Write a Python function that takes a sentence as input and returns its embedding by averaging the GloVe word embeddings of its words.
#
# ---
#
# ### Part 1: Implement the Embedding Function
#
# * Use pre-trained GloVe embeddings (e.g., 50d, 100d, or 300d).
# * Ignore words not found in the embeddings.
# * Return the average vector of all word embeddings in the sentence.
#
# ---
#
# ### Part 2: Semantic Similarity Testing
#
# After implementing the function:
#
# 1. Compute embeddings for **pairs of sentences**.
# 2. Calculate the **cosine similarity** between the pairs.
# 3. Observe which pairs have **high similarity (close)** and which have **low similarity (distant)**.
#
# ---
#
# ### Suggested Sentence Pairs to Test
#
# | Sentence 1                                     | Sentence 2                                         | Expected Similarity         |
# | ---------------------------------------------- | -------------------------------------------------- | --------------------------- |
# | "The cat sat on the mat."                      | "A cat is sitting on a mat."                       | High similarity             |
# | "He likes playing football."                   | "She enjoys watching soccer."                      | Medium similarity (related) |
# | "The weather is sunny today."                  | "I am reading a book."                             | Low similarity              |
# | "The quick brown fox jumps over the lazy dog." | "A fast dark-colored fox leaps over a sleepy dog." | High similarity             |
#
# ---
#
# ### Bonus:
#
# * Experiment with your own pairs of sentences.
# * Try to explain why some pairs have higher or lower similarity.
#
# ---
#
# ### Optional Starter for Cosine Similarity
#
# ```python
# from numpy import dot
# from numpy.linalg import norm
#
# def cosine_similarity(vec1, vec2):
#     return dot(vec1, vec2) / (norm(vec1) * norm(vec2))
# ```
