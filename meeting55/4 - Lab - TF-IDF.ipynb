# %% [markdown]
# # Exercise: Automatic Keyword Extraction Using TF-IDF
#
# **Context:**
# You have learned about the TF-IDF (Term Frequency-Inverse Document Frequency) technique to identify important keywords in documents by weighting words based on their frequency in a document and rarity across the corpus.
#
# ---
#
# ### Task:
#
# Using the **`ag_news_subset`** dataset from TensorFlow, write a Python script that:
#
# 1. Loads the dataset (train split).
# 2. For each news article (text), computes the TF-IDF scores of its words.
# 3. Extracts the **top N keywords** (words with the highest TF-IDF scores) as tags for that news article.
# 4. Outputs the article’s headline (or first few words) alongside its extracted tags.
#
# ---
#
# ### Hints:
#
# * Use **`TfidfVectorizer`** from `sklearn.feature_extraction.text`.
# * Preprocess text as needed (e.g., lowercase, remove stopwords).
# * Set **N = 3** (top 3 keywords) by default.
# * Print sample output for the first 5 news articles.
