# %% [markdown]
# <a href="https://colab.research.google.com/github/valeria-edulabs/ai-experts/blob/main/meeting11/Pandas_EDA_part_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import seaborn as sns

sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
from matplotlib import rcParams

# figure size in inches
rcParams['figure.figsize'] = 11.7,8.27

# %% [markdown]
# ## Loading data + Basic Pandas types
# 120 years of Olympic history: athletes and results
# basic bio data on athletes and medal results from Athens 1896 to Rio 2016
# https://www.kaggle.com/heesoo37/120-years-of-olympic-history-athletes-and-results

# %%
type(pd)
# Out:
# module

# %%
df = pd.read_csv('https://storage.googleapis.com/ai-experts/datasets/athlete_events.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %% [markdown]
# ## Other options to create / load dataframe

# %%
data = {
    'name': ['Sivan', 'Moshe', 'Dina'],
    'math': [76, 98, 99],
    'english': [89, 79, 100]
}

# %%
test_df = pd.DataFrame(data)

# %%
test_df

# %%
series = pd.Series([1, 13, 14, 23], dtype=int, name='grades')

# %%
series

# %%
test_df['new_grades'] = series

# %%
test_df

# %% [markdown]
# ## Basic summary methods

# %%
type(df['City'])
# Out:
# pandas.core.series.Series

# %%
df.head(10)

# %%
df.tail(70)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
df.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
len(df)
# Out:
# 271116

# %%
df.shape
# Out:
# (271116, 15)

# %% [markdown]
# ## Columns selection

# %%
df.head(3)

# %%
# single column
# print(df['Age'])
# df[df['Age'] == 97]

# %%
df['Age']
# Out:
# 0         24.0
# 1         23.0
# 2         24.0
# 3         34.0
# 4         21.0
#           ...
# 271111    29.0
# 271112    27.0
# 271113    27.0
# 271114    30.0
# 271115    34.0
# Name: Age, Length: 271116, dtype: float64

# %%
df[['Age']]
# Out:
#          Age
# 0       24.0
# 1       23.0
# 2       24.0
# 3       34.0
# 4       21.0
# ...      ...
# 271111  29.0
# 271112  27.0
# 271113  27.0
# 271114  30.0
# 271115  34.0
#
# [271116 rows x 1 columns]

# %%
df[['Age', 'Weight', 'Height']]

# %%
df.Age
# Out:
# 0         24.0
# 1         23.0
# 2         24.0
# 3         34.0
# 4         21.0
#           ...
# 271111    29.0
# 271112    27.0
# 271113    27.0
# 271114    30.0
# 271115    34.0
# Name: Age, Length: 271116, dtype: float64

# %%
df[['Age','City']]

# %%
# not working
df['Age', 'City']

# %%
df
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %% [markdown]
# ## Indexing

# %%
df
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
df1
# Out:
#                               ID Sex   Age  Height  Weight            Team  \
# Name
# A Dijiang                      1   M  24.0   180.0    80.0           China
# A Lamusi                       2   M  23.0   170.0    60.0           China
# Gunnar Nielsen Aaby            3   M  24.0     NaN     NaN         Denmark
# Edgar Lindenau Aabye           4   M  34.0     NaN     NaN  Denmark/Sweden
# Christine Jacoba Aaftink       5   F  21.0   185.0    82.0     Netherlands
# ...                          ...  ..   ...     ...     ...             ...
# Andrzej ya                135569   M  29.0   179.0    89.0        Poland-1
# Piotr ya                  135570   M  27.0   176.0    59.0          Poland
# Piotr ya                  135570   M  27.0   176.0    59.0          Poland
# Tomasz Ireneusz ya        135571   M  30.0   185.0    96.0          Poland
# Tomasz Ireneusz ya        135571   M  34.0   185.0    96.0          Poland
#
# ...

# %%
df1 = df.set_index("Name")

# %%
df1
# Out:
#                               ID Sex   Age  Height  Weight            Team  \
# Name
# A Dijiang                      1   M  24.0   180.0    80.0           China
# A Lamusi                       2   M  23.0   170.0    60.0           China
# Gunnar Nielsen Aaby            3   M  24.0     NaN     NaN         Denmark
# Edgar Lindenau Aabye           4   M  34.0     NaN     NaN  Denmark/Sweden
# Christine Jacoba Aaftink       5   F  21.0   185.0    82.0     Netherlands
# ...                          ...  ..   ...     ...     ...             ...
# Andrzej ya                135569   M  29.0   179.0    89.0        Poland-1
# Piotr ya                  135570   M  27.0   176.0    59.0          Poland
# Piotr ya                  135570   M  27.0   176.0    59.0          Poland
# Tomasz Ireneusz ya        135571   M  30.0   185.0    96.0          Poland
# Tomasz Ireneusz ya        135571   M  34.0   185.0    96.0          Poland
#
# ...

# %% [markdown]
# ## Row selection by order

# %%
row = df1.iloc[1]

# %%
type(row)
# Out:
# pandas.core.series.Series

# %%
row.index
# Out:
# Index(['ID', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games', 'Year',
#        'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
df1.iloc[10:20:2]
# Out:
#                  ID Sex   Age  Height  Weight           Team  NOC  \
# Name
# Per Knut Aaland   6   M  31.0   188.0    75.0  United States  USA
# Per Knut Aaland   6   M  31.0   188.0    75.0  United States  USA
# Per Knut Aaland   6   M  33.0   188.0    75.0  United States  USA
# Per Knut Aaland   6   M  33.0   188.0    75.0  United States  USA
# John Aalberg      7   M  31.0   183.0    72.0  United States  USA
#
#                        Games  Year  Season         City                 Sport  \
# Name
# Per Knut Aaland  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# Per Knut Aaland  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# Per Knut Aaland  1994 Winter  1994  Winter  Lillehammer  Cross Country Skiing
# Per Knut Aaland  1994 Winter  1994  Winter  Lillehammer  Cross Country Skiing
# John Aalberg     1992 Winter  1992  Winter  Albertville  Cross Country Skiing
#
#                                                              Event Medal
# Name
# ...

# %%
df1.iloc[[2, 5]]

# %% [markdown]
# ## Index and Rows Selection

# %%
df1.loc["Piotr ya"]
# Out:
#               ID Sex   Age  Height  Weight    Team  NOC        Games  Year  \
# Name
# Piotr ya  135570   M  27.0   176.0    59.0  Poland  POL  2014 Winter  2014
# Piotr ya  135570   M  27.0   176.0    59.0  Poland  POL  2014 Winter  2014
#
#           Season   City        Sport  \
# Name
# Piotr ya  Winter  Sochi  Ski Jumping
# Piotr ya  Winter  Sochi  Ski Jumping
#
#                                              Event Medal
# Name
# Piotr ya  Ski Jumping Men's Large Hill, Individual   NaN
# Piotr ya        Ski Jumping Men's Large Hill, Team   NaN

# %%
df1.loc[3]

# %%
df
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
df.index = list(range(10, 10 + 271116))

# %%
df

# %%
df = df.reset_index(drop=True)

# %%
df.drop(columns=["index"])

# %%
df.reset_index()

# %%
df.set_index(["Year", "Sex"]).loc[("F")]

# %%
df.set_index(["Year", "Sex"]).loc[(2000, "F")]

# %%
df.set_index("Name", inplace=True)

# %%
df.loc["Christine Jacoba Aaftink", "Age"]
# Out:
# Name
# Christine Jacoba Aaftink    21.0
# Christine Jacoba Aaftink    21.0
# Christine Jacoba Aaftink    25.0
# Christine Jacoba Aaftink    25.0
# Christine Jacoba Aaftink    27.0
# Christine Jacoba Aaftink    27.0
# Name: Age, dtype: float64

# %%
df.loc["Christine Jacoba Aaftink", ["Age", "Year"]]
# Out:
#                            Age  Year
# Name
# Christine Jacoba Aaftink  21.0  1988
# Christine Jacoba Aaftink  21.0  1988
# Christine Jacoba Aaftink  25.0  1992
# Christine Jacoba Aaftink  25.0  1992
# Christine Jacoba Aaftink  27.0  1994
# Christine Jacoba Aaftink  27.0  1994

# %%
df.reset_index(inplace=True)

# %%
df.reset_index().loc[]

# %%
df.set_index("Name")

# %%
df.loc[10010:10000:-1, ["Age"]]
# Out:
#         Age
# 10010  28.0
# 10009  25.0
# 10008  19.0
# 10007   NaN
# 10006   NaN
# 10005  21.0
# 10004  21.0
# 10003  21.0
# 10002  21.0
# 10001  21.0
# 10000  21.0

# %%
df.loc[2:20:4]

# %%
df.loc[20:2:-1]

# %%
df.loc[[1,7]]

# %%
df

# %%
df1 = df.set_index('Name')

# %%
df1

# %%
df1.loc['Piotr ya']

# %%
df1.iloc['Piotr ya']

# %%
df1.loc[0]

# %%
df1.iloc[-2]

# %%
df1

# %%
df.set_index('Name', inplace=True)

# %%
df1

# %%
df1.iloc[2]

# %%
df1.loc['Christine Jacoba Aaftink']

# %%
df1['City']

# %%
df1['City'].iloc[2]

# %%
df1.iloc[3]

# %%
df1.loc['Piotr ya', 'Age']

# %%
df1.reset_index(inplace=True)

# %%
df1

# %%
df1 = df.set_index(['City', 'Year']).sort_index()

# %%
df1.loc['Albertville']

# %%
df.set_index(['City', 'Year']).index

# %%
df1.index

# %%
df1

# %%
df1.reset_index(inplace=True)

# %%
df1

# %% [markdown]
# ## Selection by index and columns

# %%
df['Age']

# %%
df.loc[10:20, ['Age', 'Name']]

# %%
df.loc[10:20, :]

# %%
df.iloc[10:20, 2:3]

# %% [markdown]
# ## Copy

# %%
my_df = df.copy(deep=True)

# %%
my_df = df

# %%
# my_df.set_index('Age', inplace=True)

# %% [markdown]
# ## Element-wise Operations

# %%
df['Age'] + 5

# %%
df[['Age', 'Weight', 'Height']] + 100

# %%
df[['City']] + '100'

# %% [markdown]
# ## Masks and filter

# %%
df['Age'] == 10
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 271111    False
# 271112    False
# 271113    False
# 271114    False
# 271115    False
# Name: Age, Length: 271116, dtype: bool

# %%
df[(df['Age'] == 10) | (df['Age'] > 80)]

# %%
df[df["Age"]]

# %%
df[['Age']] == 10

# %%
df[['Height', 'Weight']] == 100

# %%
df != 100

# %%
df[df['Age'] == 10]

# %%
df['Age'] >=80

# %%
df.loc[[10, 80]]

# %%
df[df['Age'] >=80]

# %%
mask = (df['Age'] > 30) & (df['Team'] == 'Israel')

# %%
df[mask]

# %%
df[(df['Team'] == 'Israel') & (~df['Medal'].isna())].sort_values("Age")
# Out:
#                                Name      ID Sex   Age  Height  Weight    Team  \
# 73099                   Gal Fridman   37163   M  20.0   183.0    68.0  Israel
# 270589                Shahar Zubari  135332   M  21.0   177.0    68.0  Israel
# 223070             Shay-Oren Smadja  112033   M  22.0     NaN     NaN  Israel
# 8686                      Yael Arad    4771   F  25.0     NaN     NaN  Israel
# 123081  Michael (-Mikhail) Kolganov   62204   M  25.0   185.0    89.0  Israel
# 211004                    Or Sasson  105958   M  25.0   193.0   120.0  Israel
# 78166                  Yarden Gerbi   39695   F  27.0   169.0    63.0  Israel
# 268223          Ariel "Arik" Ze'evi  134194   M  27.0   186.0   100.0  Israel
# 73100                   Gal Fridman   37163   M  28.0   183.0    68.0  Israel
#
#         NOC        Games  Year  Season            City     Sport  \
# 73099   ISR  1996 Summer  1996  Summer         Atlanta   Sailing
# ...

# %% [markdown]
# ## Column addition

# %%
df['Is_Child'] = df['Age'] <= 16

# %%
df[df["Age"].isna()]

# %%
(df['Age'] <= 16).loc[147]
# Out:
# False

# %%
df

# %%
df[df["Is_Child"]]

# %%
df[["Age10", "Height10"]] = df[["Age", "Height"]] + 10

# %% [markdown]
# ## Column deletion

# %%
# drop - both columns and rows
df.drop(columns=['Is_Child'], inplace=True)

# %%
df.index

# %%
df.drop(df.index[30:40])

# %% [markdown]
# ## Columns update

# %%
df1 = df.copy()

# %%
df1['Age'] = df1['Age'] + 10

# %%
#astype
# df['Sex'] = 'Female' if df['Sex'] == 'F' else 'Male'
df.dropna(inplace=True)
new_age = df['Age'].astype(int)

# %%
df

# %%
df['Age'] = df['Age'].astype(int)

# %%
df['Age'] = df[~df['Age'].isna()]['Age'].astype(int)

# %%
df

# %%
df[~df['Age'].isna()]['Age'].astype(int)
