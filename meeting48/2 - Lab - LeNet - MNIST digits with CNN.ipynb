# %% [markdown]
# # Task
#
# Your task is to recreate LeNet-5 architecture for MNIST digits dataset
#
# You can find the original article [here](http://vision.stanford.edu/cs598_spring07/papers/Lecun98.pdf)
#
# *Note: you can skip implementing Complex connectivity pattern introduced originally in C3 layer*

# %% [markdown]
# | Layer  | Type                  | Output Size | Notes                        |
# | ------ | --------------------- | ----------- | ---------------------------- |
# | C1     | Convolution (6×5×5)   | 28×28×6     | No padding                   |
# | S2     | Average Pooling (2×2) | 14×14×6     | Subsampling                  |
# | C3     | Convolution           | 10×10×16    | Complex connectivity pattern |
# | S4     | Average Pooling       | 5×5×16      |                              |
# | C5     | Convolution (FC)      | 1×1×120     | Fully connected to S4        |
# | F6     | Fully Connected       | 84          | Classic dense layer          |
# | Output | Fully Connected       | 10          | Softmax over digit classes   |

# %%
import os
import datetime

# TensorFlow and tf.keras
import tensorflow as tf

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

# Make NumPy printouts easier to read.
np.set_printoptions(precision=2, suppress=True)


import plotly.express as px

# %% [markdown]
# # Data

# %%
from keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
