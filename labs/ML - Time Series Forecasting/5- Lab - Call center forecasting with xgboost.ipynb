# %% [markdown]
# # Imports and configs

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
from random import gauss
from random import seed
from pandas import Series
from pandas.plotting import autocorrelation_plot
from matplotlib import pyplot
from plotly.subplots import make_subplots
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.stats.diagnostic import acorr_ljungbox
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error
import pandas as pd
import numpy as np
import warnings
from sklearn import metrics

# %%
pd.options.plotting.backend = "plotly"

# %%
data_path = "https://storage.googleapis.com/edulabs-public-datasets/callcenter.csv"

# %% [markdown]
# # Load the data

# %%
df = pd.read_csv(data_path, parse_dates=['QueueStartDate'], dayfirst=True)

# %%
df.head()
# Out:
#   QueueStartDate QueueStartDateName       Interval   CallTypeName  \
# 0     2024-01-01             Monday  08:00 - 08:30       HdKamuti
# 1     2024-01-01             Monday  08:00 - 08:30      ShlihimCB
# 2     2024-01-01             Monday  08:30 - 09:00  HouseDelivery
# 3     2024-01-01             Monday  08:30 - 09:00   SuperVisor_L
# 4     2024-01-01             Monday  09:00 - 09:30   Appointments
#
#    CallsOffered  CallsAnswered  CallsAbonded  CallbackRequest  \
# 0             2              1             1                0
# 1             7              6             1                0
# 2             6              5             0                1
# 3             6              5             1                0
# 4            58             41             7               10
#
#    CallsTransfered  WaitDuration  ...  CallDuration  MaxCallDuration  \
# 0                0           933  ...           116              116
# 1                0           414  ...          1029              503
# 2                0            83  ...           596              283
# 3                0           149  ...          1428              435
# 4                0         14956  ...          3401              181
#
#    AvgCallDuration  P_CallsAnswered  P_CallsAbonded  P_CallsTransfered  \
# 0              116            50.00           50.00                0.0
# 1              171            85.71           14.29                0.0
# 2               99           100.00            0.00                0.0
# 3              285            83.33           16.67                0.0
# 4               66            87.93           12.07                0.0
#
#    P_CallbackRequest  TotalAgents  TotalSupervisors  TotalAgentsAndSupervisors
# 0               0.00         36.0               2.0                       38.0
# 1               0.00         36.0               2.0                       38.0
# 2              16.67         42.0               2.0                       44.0
# 3               0.00         42.0               2.0                       44.0
# 4              17.24         44.0               3.0                       47.0
#
# [5 rows x 22 columns]

# %% [markdown]
# # Preprocess the data
#
# - Create a pandas series with date index, series should contain one element (row) per total callsOffered per day
# - We are going to analyze and later predict amount of calls per day

# %%
ts = df[['QueueStartDate', 'CallsOffered']].set_index('QueueStartDate').squeeze().groupby(pd.Grouper(freq='D')).sum()

# %%
#ts.reset_index()["QueueStartDate"].dt.isocalendar().week

# %% [markdown]
# # Data visualization
#
# Display various plots and try to determine the following:
# - Does data have structure or it looks like white noise / random walk
# - Is there a trend in data?
# - Is there seasonality?
#
# Try the following plots:
# - Lines
# - Histograms
# - Boxes
# - Heat maps
# - Other

# %%
ts.plot()

# %%
px.box(ts, color=ts.index.day_name())
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7dacf721-38a0-4385-b768-3dc9c7417597" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7dacf721-38a0-4385-b768-3dc9c7417597")) {                    Plotly.newPlot(                        "7dacf721-38a0-4385-b768-3dc9c7417597",                        [{"alignmentgroup":"True","hovertemplate":"color=Monday\u003cbr\u003evariable=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Monday","marker":{"color":"#636efa"},"name":"Monday","notched":false,"offsetgroup":"Monday","orientation":"v","showlegend":true,"x":["CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered"],"x0":" ","xaxis":"x","y":[8808,10408,9486,9128,8611,8439,8773,9257,9286,9239,9767,9521,7682,9343,9587,9743,160,17,10430,7022,11098,11681,11688,12015,10516,10754,10266,10108,10773,11740,9116,9804,8648,7994,8234,265,9544,8405,9345,10087,9336,9283,6092,9874,9771,10054,9365,9775,10350,12230,12506,13418,11034],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"color=Tuesday\u003cbr\u003evariable=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tuesday","marker":{"color":"#EF553B"},"name":"Tuesday","notched":false,"offsetgroup":"Tuesday","orientation":"v","showlegend":true,"x":["CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered"],"x0":" ","xaxis":"x","y":[9234,9944,9653,7933,8236,8705,8915,9395,987,9635,9868,9960,11257,9649,9698,9809,12,9196,10542,8,11563,11981,11088,318,10824,10782,10445,10246,9838,10631,9509,6732,5757,8442,8500,11338,9493,8482,8868,8676,9261,8614,5782,9389,8914,9663,10129,9574,11635,12615,12319,12634,10442],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"color=Wednesday\u003cbr\u003evariable=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wednesday","marker":{"color":"#00cc96"},"name":"Wednesday","notched":false,"offsetgroup":"Wednesday","orientation":"v","showlegend":true,"x":["CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOff ...

# %%
px.box(ts, color=ts.index.month_name())
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4369f97f-8b7d-4aa5-921d-6a98ea5884ab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4369f97f-8b7d-4aa5-921d-6a98ea5884ab")) {                    Plotly.newPlot(                        "4369f97f-8b7d-4aa5-921d-6a98ea5884ab",                        [{"alignmentgroup":"True","hovertemplate":"color=January\u003cbr\u003evariable=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"January","marker":{"color":"#636efa"},"name":"January","notched":false,"offsetgroup":"January","orientation":"v","showlegend":true,"x":["CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered"],"x0":" ","xaxis":"x","y":[8808,9234,8648,8602,2145,0,10185,10408,9944,9842,9579,1981,0,10228,9486,9653,9799,8410,1674,0,9660,9128,7933,8647,7948,1899,0,10056,8611,8236,8923],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"color=February\u003cbr\u003evariable=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"February","marker":{"color":"#EF553B"},"name":"February","notched":false,"offsetgroup":"February","orientation":"v","showlegend":true,"x":["CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered"],"x0":" ","xaxis":"x","y":[8341,1741,0,9322,8439,8705,9018,8083,1815,0,10110,8773,8915,9346,8729,1798,0,9304,9257,9395,9505,8745,2054,0,10316,9286,987,10336,10619],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"color=March\u003cbr\u003evariable=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"March","marker":{"color":"#00cc96"},"name":"March","notched":false,"offsetgroup":"March","orientation":"v","showlegend":true,"x":["CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered"],"x0":" ","xaxis":"x","y":[2016,0,16088,9239,9635,8586,9262,2090,0,10581,9767,9868,9701,10721,1728,0,10944,9521,9960,9461,8453,2321,0,4442,7682,11257,9830,9317,2324,0,11087],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"color=April\u003cbr\u003evariable=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"April","marker":{"color":"#ab63fa"},"name":"April","notched":false,"offsetgroup":"April","orientation":"v","showlegend":true,"x":["CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered","CallsOffered" ...

# %% [markdown]
# # Is data stationary?
#
# **Determine whether your data is stationary, and if not - remove trends / seasonalities**
#
# 1. Run ADF test to find whther your data is stationary
# 2. If the data is not stationary - use differencing techniques to remove trend and seasonality
# 3. Run ADF test again after performing differencing to see whether data is stationary.
# 4. Run steps 2-3 again if needed

# %%
# Run ADF test
result = adfuller(ts)

# Display results
print("ADF Statistic:", result[0])
print("p-value:", result[1])
for key, value in result[4].items():
    print(f"Critical Value ({key}): {value}")

# %%
# lets try and remove seasonality (weekly)
ts.diff(7).dropna().plot()

# %% [markdown]
# The data looks quite stationary with some anomalies
# - the drops in calls might indicate holidays (we can axtually double-check it with hebrew calendar)
# - the peaks need to be explained

# %%
# prompt: get israel public holidays in 2024

import holidays

il_holidays = holidays.Israel(years=2024)

for date, name in sorted(il_holidays.items()):
    print(date, name)

# %%
# Run ADF test
result = adfuller(ts.diff(7).dropna())

# Display results
print("ADF Statistic:", result[0])
print("p-value:", result[1])
for key, value in result[4].items():
    print(f"Critical Value ({key}): {value}")

# %%
detrended = ts.diff(7).dropna()

# %%
px.box(detrended, color=detrended.index.month_name())

# %% [markdown]
# # Now, after the data is stationary - check whether it's white noise (can it be forecasted at all?)
#
# - Display ACF plot and check for auto-correlation
# - Run Ljung-Box Test
#
#
# Reminder:
# **Autocorrelation Plot (ACF)**
# - If no significant autocorrelation at any lag → likely white noise.
# - If significant autocorrelation at lag 1 or others → likely AR process (i.e., a differenced random walk).
#
# **Ljung-Box Test**
# - A high p-value → series are like white noise
# - A low p-value → autocorrelation exists - not a white noise

# %%
plot_acf(detrended, lags=25) # Adjust lags as needed
plt.show()

# %% [markdown]
# We can clearly see autogorrelation with 1 lag

# %%
lb_test = acorr_ljungbox(detrended, lags=10, return_df=True)
print(lb_test)

# %% [markdown]
# The data is not a noise by all means and we should be able to forecast it

# %% [markdown]
# # **Adding test data**
#
# - Our train data is daily callsOffered for 2024 (01-01-2024 -> 31-12-2024)
# - Now we added data for 2025 (01-01-2025 -> 14-01-2025)
# - You are going to train your models on data from 2024, select best params using cross-validation, abd in the end you will perform final test on the data for 2025

# %%
test_data_path = "https://storage.googleapis.com/edulabs-public-datasets/callcenter2025.csv"

# %%
test_ts = pd.read_csv(test_data_path, parse_dates=['QueueStartDate'], dayfirst=True)[['QueueStartDate', 'CallsOfferes']].set_index('QueueStartDate').squeeze()

# %% [markdown]
# # **Forecasting with xgboost**

# %% [markdown]
# **You are now going to forecast daily calls offered using xgboost algorithm**
#
# In order to use time series in an algorithm that is not naturally built for time-series, you need to manually create time-series features.
#
# - Decide how many lags back you want to include in the forecasting
# - Create those lag features (it;s better to write a generic code so you could tune lag (hint: you can use `shift`)
# - Add other holiday-based and / or time-based features - like weekday, month, etc
# - Don't forget to split your data into train / validation / test
# - Use tree-based xgboost
# - Display errors and error metrics
# - Compare this model to prophet
