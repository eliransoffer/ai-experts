# %% [markdown]
# # Imports and configurations

# %%
import datetime
from math import sqrt

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.preprocessing import StandardScaler, MinMaxScaler

#  (high-level, simple to use)
import plotly.express as px
# (low-level, highly customizable)
import plotly.graph_objects as go

from scipy import stats

# %%
# Set Plotly as Pandas plotting backend

pd.options.plotting.backend = "plotly"

# %% [markdown]
# # Load data

# %%
df = sns.load_dataset('diamonds')

# %%
df

# %% [markdown]
# # EDA

# %%
px.scatter(df, x='carat', y='price')

# %%
px.scatter(df, x='carat', y='price', color='cut')

# %%
px.scatter(df, x='carat', y='price', facet_col='cut', color='cut', title=f'Separate Scatter Plots by cut')

# %%
px.histogram(df, x='price', nbins=250)

# %% [markdown]
# # Thoughts on training the model
