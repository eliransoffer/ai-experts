# %% [markdown]
# # Data
#
# You are going to use NYC Taxt Traffic dataset.
#
# The data file included here consists of aggregating the total number of taxi passengers into 30 minute buckets.
#
# The data is also known to contain at least 5 anomalies that occur during the NYC marathon, Thanksgiving, Christmas, New Years day, and a snow storm.

# %%
data_path = "https://storage.googleapis.com/edulabs-public-datasets/nyc_taxi_traffic.csv"

# %% [markdown]
# # The Task
#
# Your task is to rin various algorithms for time series anomaly detection, and detect anomalies in NYC Taxi Traffic.
#
# Check whether anomalies you detected correspond to anomalies actually occurred and registered.

# %%
import pandas as pd
