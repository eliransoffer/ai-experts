# %% [markdown]
# # Task
#
# - Select your favorite stock / index
# - Get data for this stock / index - you can either use one single feature or multiple features
# - hint: you can use APIs like yahoo finance or others to fetch the data
# - Optionally, You can train model on various stocks from the same sector, and validate on other stocks
# - Train CNN model that predicts based on X timesteps in past whether the stock price will go up or down (binary classification). Optionally, you can create your labeling strategy for SELL / BUY / HOLD and run 3 labels classification
