# %% [markdown]
# <a href="https://colab.research.google.com/github/valeria-edulabs/ai-experts/blob/main/meeting12/hw_solutionb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# Load Olympic history dataset (don't forget to upload athlete_events.csv to Colab first)
# The file can be downloaded from Kaggle:
# https://www.kaggle.com/heesoo37/120-years-of-olympic-history-athletes-and-results
#
# or from the url provided

# %%
url = 'https://storage.googleapis.com/edulabs-public-datasets/athlete_events.zip'

# %%
df = pd.read_csv(url)

# %% [markdown]
# # 1
#
# Load the dataset using optional argument dtypes and try reducing the amount of memory your dataset consumes in the memory as much as possible
#
# Hint:
# - use smalles numeric types possible
# - use categorical types
# - remove redundant columns

# %%
df
# Out:
#             ID                      Name    Sex  Age  Height  Weight  \
# 0            1                 A Dijiang   True   24     180    80.0
# 1            2                  A Lamusi   True   23     170    60.0
# 2            3       Gunnar Nielsen Aaby   True   24    <NA>     NaN
# 3            4      Edgar Lindenau Aabye   True   34    <NA>     NaN
# 4            5  Christine Jacoba Aaftink  False   21     185    82.0
# ...        ...                       ...    ...  ...     ...     ...
# 271111  135569                Andrzej ya   True   29     179    89.0
# 271112  135570                  Piotr ya   True   27     176    59.0
# 271113  135570                  Piotr ya   True   27     176    59.0
# 271114  135571        Tomasz Ireneusz ya   True   30     185    96.0
# 271115  135571        Tomasz Ireneusz ya   True   34     185    96.0
#
#                   Team  NOC  Year  Season            City          Sport  \
# 0                China  CHN  1992    True       Barcelona     Basketball
# 1                China  CHN  2012    True          London           Judo
# 2              Denmark  DEN  1920    True       Antwerpen       Football
# 3       Denmark/Sweden  DEN  1900    True           Paris     Tug-Of-War
# 4          Netherlands  NED  1988   False         Calgary  Speed Skating
# ...                ...  ...   ...     ...             ...            ...
# 271111        Poland-1  POL  1976   False       Innsbruck           Luge
# 271112          Poland  POL  2014   False           Sochi    Ski Jumping
# 271113          Poland  POL  2014   False           Sochi    Ski Jumping
# 271114          Poland  POL  1998   False          Nagano      Bobsleigh
# 271115          Poland  POL  2002   False  Salt Lake City      Bobsleigh
#
#                                            Event Medal
# 0                    Basketball Men's Basketball   NaN
# 1                   Judo Men's Extra-Lightweight   NaN
# 2                        Football Men's Football   NaN
# 3                    Tug-Of-War Men's Tug-Of-War  Gold
# 4               Speed Skating Women's 500 metres   NaN
# ...                                          ...   ...
# 271111                Luge Mixed (Men)'s Doubles   NaN
# 271112  Ski Jumping Men's Large Hill, Individual   NaN
# 271113        Ski Jumping Men's Large Hill, Team   NaN
# 271114                      Bobsleigh Men's Four   NaN
# 271115                      Bobsleigh Men's Four   NaN
#
# [271116 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
converters = {
    "Sex": lambda s: s == 'M', # return True if Male, false if Female
    "Season": lambda s: s == 'Summer'  # return True if Summer, false if Winter
}
dtypes = {
    "ID": "int32",
    "Age": "Int8",
    "Height": "Int16",
    "Weight": "float32",
    "Year": "Int16",
    "Medal": "category"
}
usecols = [
    'ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC',
       'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'
]  # all the columns except for "Games" which is redundant

df = pd.read_csv(url, usecols=usecols, converters=converters, dtype=dtypes)
# Out:
#             ID                      Name    Sex  Age  Height  Weight  \
# 0            1                 A Dijiang   True   24     180    80.0
# 1            2                  A Lamusi   True   23     170    60.0
# 2            3       Gunnar Nielsen Aaby   True   24    <NA>     NaN
# 3            4      Edgar Lindenau Aabye   True   34    <NA>     NaN
# 4            5  Christine Jacoba Aaftink  False   21     185    82.0
# ...        ...                       ...    ...  ...     ...     ...
# 271111  135569                Andrzej ya   True   29     179    89.0
# 271112  135570                  Piotr ya   True   27     176    59.0
# 271113  135570                  Piotr ya   True   27     176    59.0
# 271114  135571        Tomasz Ireneusz ya   True   30     185    96.0
# 271115  135571        Tomasz Ireneusz ya   True   34     185    96.0
#
#                   Team  NOC  Year  Season            City          Sport  \
# 0                China  CHN  1992    True       Barcelona     Basketball
# 1                China  CHN  2012    True          London           Judo
# 2              Denmark  DEN  1920    True       Antwerpen       Football
# 3       Denmark/Sweden  DEN  1900    True           Paris     Tug-Of-War
# 4          Netherlands  NED  1988   False         Calgary  Speed Skating
# ...                ...  ...   ...     ...             ...            ...
# 271111        Poland-1  POL  1976   False       Innsbruck           Luge
# 271112          Poland  POL  2014   False           Sochi    Ski Jumping
# 271113          Poland  POL  2014   False           Sochi    Ski Jumping
# 271114          Poland  POL  1998   False          Nagano      Bobsleigh
# 271115          Poland  POL  2002   False  Salt Lake City      Bobsleigh
#
#                                            Event Medal
# 0                    Basketball Men's Basketball   NaN
# 1                   Judo Men's Extra-Lightweight   NaN
# 2                        Football Men's Football   NaN
# 3                    Tug-Of-War Men's Tug-Of-War  Gold
# 4               Speed Skating Women's 500 metres   NaN
# ...                                          ...   ...
# 271111                Luge Mixed (Men)'s Doubles   NaN
# 271112  Ski Jumping Men's Large Hill, Individual   NaN
# 271113        Ski Jumping Men's Large Hill, Team   NaN
# 271114                      Bobsleigh Men's Four   NaN
# 271115                      Bobsleigh Men's Four   NaN
#
# [271116 rows x 14 columns]

# %%
# note reduction of memory from 31MB to 17 MB
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 14 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int32
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  bool
#  3   Age     261642 non-null  Int8
#  4   Height  210945 non-null  Int16
#  5   Weight  208241 non-null  float32
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Year    271116 non-null  Int16
#  9   Season  271116 non-null  bool
#  10  City    271116 non-null  object
#  11  Sport   271116 non-null  object
#  12  Event   271116 non-null  object
#  13  Medal   39783 non-null   category
# dtypes: Int16(2), Int8(1), bool(2), category(1), float32(1), int32(1), object(6)
# memory usage: 17.3+ MB

# %% [markdown]
# # 2
#
# Update original dataframe - add boolean "Is_summer" column based on "season" column and set the values accordingly

# %%
# renaming the columns
df.rename(columns={"Sex": "male", "Season": "summer"}, inplace=True)
df.rename(columns={col: col.lower() for col in df.columns}, inplace=True)

# %% [markdown]
# # 3
#
# How many NaN and no-NaN values in Height column?

# %%
print(f"Nan values: {df['height'].isna().sum()}")
print(f"Non-Nan values: {df['height'].count()}")
# Out:
# Nan values: 60171
# Non-Nan values: 210945

# %% [markdown]
# # 4
#
# Create a dataframe that displays max and min values for the following columns: weight, height, age

# %%
df[['height', 'weight', 'age']].agg(['max', 'min'])
# Out:
#      height  weight  age
# max     226   214.0   97
# min     127    25.0   10

# %% [markdown]
# # 5
# Filter athlete_events dataframe - display rows of women that participated Winter Olympic games between 1996 and 2002.
# How many rows are there?

# %%
filtered = df[(df['year'] >= 1996) & (df['year'] <=2002) & (df['male'] == False)]

# %%
# displaying
filtered
# Out:
#             id                       name   male  age  height  weight  \
# 32          13         Minna Maarit Aalto  False   30     159    55.5
# 33          13         Minna Maarit Aalto  False   34     159    55.5
# 105         37         Ann Kristin Aarnes  False   23     182    64.0
# 259        131              Tran Abbasova  False   33     159    53.0
# 280        147              Joanne Abbott  False   41     160    57.0
# ...        ...                        ...    ...  ...     ...     ...
# 271062  135550  Vera Vasilyevna Zyatikova  False   27     161    53.0
# 271063  135550  Vera Vasilyevna Zyatikova  False   27     161    53.0
# 271064  135550  Vera Vasilyevna Zyatikova  False   27     161    53.0
# 271065  135550  Vera Vasilyevna Zyatikova  False   27     161    53.0
# 271102  135563  Olesya Nikolayevna Zykina  False   19     171    64.0
#
#               team  noc  year  summer            city                 sport  \
# 32         Finland  FIN  1996    True         Atlanta               Sailing
# 33         Finland  FIN  2000    True          Sydney               Sailing
# 105         Norway  NOR  1996    True         Atlanta              Football
# 259     Azerbaijan  AZE  2000    True          Sydney         Weightlifting
# 280         Canada  CAN  1996    True         Atlanta               Sailing
# ...            ...  ...   ...     ...             ...                   ...
# 271062     Belarus  BLR  2002   False  Salt Lake City  Cross Country Skiing
# 271063     Belarus  BLR  2002   False  Salt Lake City  Cross Country Skiing
# 271064     Belarus  BLR  2002   False  Salt Lake City  Cross Country Skiing
# 271065     Belarus  BLR  2002   False  Salt Lake City  Cross Country Skiing
# 271102      Russia  RUS  2000    True          Sydney             Athletics
#
#                                                     event   medal
# 32                             Sailing Women's Windsurfer     NaN
# 33                             Sailing Women's Windsurfer     NaN
# 105                             Football Women's Football  Bronze
# 259                   Weightlifting Women's Featherweight     NaN
# 280                   Sailing Mixed Three Person Keelboat     NaN
# ...                                                   ...     ...
# 271062         Cross Country Skiing Women's 10 kilometres     NaN
# 271063         Cross Country Skiing Women's 15 kilometres     NaN
# 271064  Cross Country Skiing Women's 5/5 kilometres Pu...     NaN
# 271065  Cross Country Skiing Women's 4 x 5 kilometres ...     NaN
# 271102             Athletics Women's 4 x 400 metres Relay  Bronze
#
# [13405 rows x 14 columns]

# %% [markdown]
# # 6
# Display data for Israeli teams only.
# How many rows are there?

# %%
israeli_rows_only = df[df['noc'] == 'ISR']
israeli_rows_only
# Out:
#             id           name   male  age  height  weight    team  noc  year  \
# 705        403    Ruth Abeles  False   18     153    48.0  Israel  ISR  1960
# 706        403    Ruth Abeles  False   18     153    48.0  Israel  ISR  1960
# 707        403    Ruth Abeles  False   18     153    48.0  Israel  ISR  1960
# 708        403    Ruth Abeles  False   18     153    48.0  Israel  ISR  1960
# 709        403    Ruth Abeles  False   18     153    48.0  Israel  ISR  1960
# ...        ...            ...    ...  ...     ...     ...     ...  ...   ...
# 270590  135332  Shahar Zubari   True   25     177    68.0  Israel  ISR  2012
# 270591  135332  Shahar Zubari   True   29     177    68.0  Israel  ISR  2016
# 270712  135382  Eli Zuckerman   True   27     177    60.0  Israel  ISR  2000
# 270847  135458       Rami Zur   True   23     175    77.0  Israel  ISR  2000
# 270848  135458       Rami Zur   True   23     175    77.0  Israel  ISR  2000
#
#         summer            city       sport  \
# 705       True            Roma  Gymnastics
# 706       True            Roma  Gymnastics
# 707       True            Roma  Gymnastics
# 708       True            Roma  Gymnastics
# 709       True            Roma  Gymnastics
# ...        ...             ...         ...
# 270590    True          London     Sailing
# 270591    True  Rio de Janeiro     Sailing
# 270712    True          Sydney     Sailing
# 270847    True          Sydney    Canoeing
# 270848    True          Sydney    Canoeing
#
#                                              event medal
# 705       Gymnastics Women's Individual All-Around   NaN
# 706              Gymnastics Women's Floor Exercise   NaN
# 707                 Gymnastics Women's Horse Vault   NaN
# 708                 Gymnastics Women's Uneven Bars   NaN
# 709                Gymnastics Women's Balance Beam   NaN
# ...                                            ...   ...
# 270590                    Sailing Men's Windsurfer   NaN
# 270591                    Sailing Men's Windsurfer   NaN
# 270712             Sailing Men's Two Person Dinghy   NaN
# 270847    Canoeing Men's Kayak Doubles, 500 metres   NaN
# 270848  Canoeing Men's Kayak Doubles, 1,000 metres   NaN
#
# [665 rows x 14 columns]

# %% [markdown]
# # 7
# How many Israeli athletes participated ever in Olympic games?
#
# Does the number you received differ from the previous one? Why?

# %%
israeli_rows_only['id'].nunique()
# Out:
# 353

# %% [markdown]
# # 8
# Create a dataframe with data about  how many Israeli athlets participated in Olympic games per year per season.

# %%
israelis_per_games = israeli_rows_only[['year','summer','id']].groupby(['year','summer']).nunique()
israelis_per_games
# Out:
#              id
# year summer
# 1952 True    25
# 1956 True     3
# 1960 True    23
# 1964 True    10
# 1968 True    29
# 1972 True    14
# 1976 True    26
# 1984 True    32
# 1988 True    18
# 1992 True    30
# 1994 False    1
# 1996 True    25
# 1998 False    3
# 2000 True    39
# 2002 False    5
# 2004 True    36
# 2006 False    5
# 2008 True    43
# 2010 False    3
# 2012 True    37
# 2014 False    4
# 2016 True    47

# %% [markdown]
# # 9
# Display names of israeli athlets and amount of Olympic games they participated in descending (from athlets that participated in most games to less games)
#
# Display a name of Israeli athlete that participated in most olympic games

# %%
most_participating = israeli_rows_only[['year', 'id', "name"]] \
    .groupby(['id', 'name']).nunique() \
    .rename(columns={'year': 'participated'}) \
    .sort_values('participated', ascending=False)
most_participating
# Out:
#                                       participated
# id     name
# 114412 Guy Starik                                4
# 40813  Anastasia Gloushkov Leventhal             4
# 134194 Ariel "Arik" Ze'evi                       4
# 108419 Yoel Sela                                 4
# 85543  Gal Nevo                                  3
# ...                                            ...
# 47131  Mordechai (Marcel) Hefez                  1
# 46602  Itzhak Hatuel                             1
# 46601  Delila Hatuel                             1
# 45580  Liat Hani Novitz                          1
# 135458 Rami Zur                                  1
#
# [353 rows x 1 columns]

# %% [markdown]
# # 10
# Create a dataframe that displays how many athlets participated per olympic games per country

# %%
athlets_per_country = df[['year', 'summer', 'noc', 'id']].groupby(['year', 'summer','noc']).nunique().sort_index()
athlets_per_country
# Out:
#                  id
# year summer noc
# 1896 True   AUS   1
#             AUT   3
#             DEN   3
#             FRA  12
#             GBR  10
# ...              ..
# 2016 True   VIE  22
#             VIN   4
#             YEM   3
#             ZAM   7
#             ZIM  30
#
# [3837 rows x 1 columns]

# %% [markdown]
# # 11
# Create a dataframe that presents how many medals each country earned per Games per medal type

# %%
medals_stats = df[~df['medal'].isna()].groupby(['year', 'summer', 'noc', 'medal'], observed=True).count()['event'].sort_index()
medals_stats
# Out:
# year  summer  noc  medal
# 1896  True    AUS  Bronze    1
#                    Gold      2
#               AUT  Bronze    2
#                    Gold      2
#                    Silver    1
#                             ..
# 2016  True    UZB  Silver    2
#               VEN  Bronze    2
#                    Silver    1
#               VIE  Gold      1
#                    Silver    1
# Name: event, Length: 3676, dtype: int64

# %% [markdown]
# # 12
# Using the dataframe you created, find out which country won most Gold medals in 2016 Olympic games

# %%
medals_stats.loc[2016, True, :, 'Gold'].sort_values(ascending=False).iloc[0:1]
# Out:
# noc
# USA    139
# Name: event, dtype: int64

# %% [markdown]
# # 13
#
# Create a dataframe that presents how many medals per medal type every country earned during all the Olympic games in history

# %%
total_medals = df.groupby(['noc','medal'], observed=True).count()[['event']].rename(columns={'event': 'total_medals'})
total_medals
# Out:
#             total_medals
# noc medal
# AFG Bronze             2
# AHO Silver             1
# ALG Bronze             8
#     Gold               5
#     Silver             4
# ...                  ...
# ZAM Bronze             1
#     Silver             1
# ZIM Bronze             1
#     Gold              17
#     Silver             4
#
# [362 rows x 1 columns]
